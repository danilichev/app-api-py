# %%
from facenet_pytorch import MTCNN
from PIL import Image
import os
import torch

# %%
gpu_indx = 0
device = torch.device(gpu_indx if torch.cuda.is_available() else 'cpu')

workers = 0 if os.name == 'nt' else 4

# %%
mtcnn = MTCNN(device=device, post_process=False)

# %%
img_path = '../data/ben.jpeg'
img_aligned_path = '../temp/ben_aligned.jpg'

img = Image.open(img_path)

img_aligned, prob = mtcnn(img, return_prob=True, save_path=img_aligned_path)

print(img_aligned.shape)
print(prob)

Image.open(img_aligned_path)
# Out:
# torch.Size([3, 160, 160])
# 0.9999850988388062
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=160x160>
